# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohsenbpb/CF-Workers-SpeedTestURL/blob/main/another_copy_of_diffuzers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
/
/!apt update Ubuntu -qqqqq
# Out:
# E: The update command takes no arguments

# %%
# !diffuzers app --port 10000  & npx localtunnel --port 10000
